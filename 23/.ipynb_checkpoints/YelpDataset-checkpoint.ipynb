# %%
import pandas as pd
import json

# %%
data = pd.read_json("yelp_academic_dataset_business.json", lines = True)
data
# Out:
#                    business_id                     name               address  \
# 0       6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom          921 Pearl St
# 1       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX   7000 NE Airport Way
# 2       bvN78flM8NLprQ1a1y5dRg           The Reclaimory    4720 Hawthorne Ave
# 3       oaepsyvc0J17qwi8cfrOWg              Great Clips    2566 Enterprise Rd
# 4       PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus   1046 Memorial Dr SE
# ...                        ...                      ...                   ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q       Eleven Oaks Realty
# 160581  bQX-kwVTyZgcdZGEPzce6Q             Webb's Honey    21777 State Rd 520
# 160582  wvFZ06nmPmQ2-IVoPqVYLA    Painting with a Twist  2164 S Chickasaw Trl
# 160583  GB75wPibj3IjNauaoCxyGA              Havana Cafe        910 NW 14th St
# 160584  ngmLL5Y5OT-bYHKU0kKrYA              Zora Grille   1370 E Altamonte Dr
#
#                      city state postal_code   latitude   longitude  stars  \
# 0                 Boulder    CO       80302  40.017544 -105.283348    4.0
# 1                Portland    OR       97218  45.588906 -122.593331    4.0
# 2                Portland    OR       97214  45.511907 -122.613693    4.5
# 3             Orange City    FL       32763  28.914482  -81.295979    3.0
# 4                 Atlanta    GA       30316  33.747027  -84.353424    4.0
# ...                   ...   ...         ...        ...         ...    ...
# 160580             Austin    TX       78701  30.272921  -97.744386    4.0
# 160581            Orlando    FL       32833  28.499836  -81.047478    4.5
# 160582            Orlando    FL       32825  28.511615  -81.270020    5.0
# 160583           Portland    OR       97209  45.529647 -122.685153    4.0
# 160584  Altamonte Springs    FL       32701  28.663047  -81.346728    4.5
#
#         review_count  is_open  \
# 0                 86        1
# 1                126        1
# 2                 13        1
# 3                  8        1
# 4                 14        1
# ...              ...      ...
# 160580             8        1
# 160581            18        1
# 160582             8        0
# 160583            10        1
# 160584            82        0
#
#                                                attributes  \
# 0       {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2       {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3       {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4       {'GoodForKids': 'False', 'BusinessParking': '{...
# ...                                                   ...
# 160580                                               None
# 160581  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 160582  {'DogsAllowed': 'False', 'ByAppointmentOnly': ...
# 160583  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 160584  {'RestaurantsReservations': 'True', 'OutdoorSe...
#
#                                                categories  \
# 0       Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2       Antiques, Fashion, Used, Vintage & Consignment...
# 3                              Beauty & Spas, Hair Salons
# 4       Gyms, Active Life, Interval Training Gyms, Fit...
# ...                                                   ...
# 160580  Real Estate, Real Estate Services, Home Servic...
# 160581      Health Markets, Food, Specialty Food, Grocery
# 160582  Arts & Entertainment, Paint & Sip, Art Classes...
# 160583              Cuban, Sandwiches, Restaurants, Cafes
# 160584  Restaurants, Middle Eastern, Mediterranean, Pe...
#
#                                                     hours
# 0       {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2       {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                                    None
# 4       {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...
# ...                                                   ...
# 160580  {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...
# 160581  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# 160582  {'Monday': '0:0-0:0', 'Wednesday': '12:0-17:0'...
# 160583                                               None
# 160584  {'Tuesday': '17:0-21:0', 'Wednesday': '17:0-21...
#
# [160585 rows x 14 columns]

# %%
df_new = data[data["categories"].str.contains("Restaurants", na = False)]
df_new.dropna(subset = ['attributes'], inplace = True)
df_new.head()
# Out:
# <ipython-input-3-7de17d2016bc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.dropna(subset = ['attributes'], inplace = True)
#                business_id                     name              address  \
# 0   6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1   tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 5   D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food         3755 Main St
# 12  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs        474 Lowell St
# 13  ufCxltuh56FF4-ZFZ6cVhg           Sister Honey's    247 E Michigan St
#
#          city state postal_code   latitude   longitude  stars  review_count  \
# 0     Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1    Portland    OR       97218  45.588906 -122.593331    4.0           126
# 5   Vancouver    BC         V5V  49.251342 -123.101333    3.5           169
# 12    Peabody    MA       01960  42.541155  -70.973438    4.0            39
# 13    Orlando    FL       32806  28.513265  -81.374707    4.5           135
#
#     is_open                                         attributes  \
# 0         1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1         1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 5         1  {'GoodForKids': 'True', 'Alcohol': 'u'none'', ...
# 12        1  {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# 13        1  {'BusinessParking': '{'garage': False, 'street...
#
#                                            categories  \
# 0   Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1   Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 5                                   Restaurants, Thai
# 12                           Food, Pizza, Restaurants
# 13  Restaurants, American (New), Bakeries, Dessert...
#
#                                                 hours
# 0   {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1   {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 5   {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...
# 12  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 13  {'Tuesday': '11:0-18:0', 'Wednesday': '11:0-18...

# %%
df_ohio = df_new[df_new['state']== 'OH']
df_ohio
# Out:
#                    business_id                          name  \
# 132     5eq56X-e9YbAKmHgUOyXSg                    Hunan Lion
# 144     Fl_7YDOMt58rTNHa7p2G4w                  Waffle House
# 149     vecuat0jOia-CJveW3ngDw        Schmidt's Sausage Haus
# 218     ZaMMUcOIngBCgxuKxFzfqg                    McDonald's
# 280     C1Jkjsqoz1AsYJy28IosQg          La Michoacana Market
# ...                        ...                           ...
# 160447  hNpnUFVW4Xm5CoShgpey7A  Bistro 2110 At the Blackwell
# 160482  cDA3nKRBdx4IH_hAYGtcVg     The Early Bird Food Truck
# 160535  furx9nQDLnKSx3gOxgbGHA           Grinders of Gahanna
# 160539  pFRZvauzfaHeymvSGwNBXw                Senor Tequilas
# 160555  cjyyjjBQXp2HdvlHKT_bCw                    Scramblers
#
#                      address        city state postal_code   latitude  \
# 132         2038 Crown Plaza    Columbus    OH       43220  40.065378
# 144            3085 Broadway  Urbancrest    OH       43123  39.900855
# 149         240 E Kossuth St    Columbus    OH       43206  39.946268
# 218     1524 Georgesville Rd    Columbus    OH       43228  39.919976
# 280       3160 S Hamilton Rd    Columbus    OH       43232  39.912139
# ...                      ...         ...   ...         ...        ...
# 160447   2110 Tuttle Park Pl    Columbus    OH       43210  40.005023
# 160482                          Columbus    OH       43201  40.006611
# 160535    921 E Johnstown Rd    Columbus    OH       43230  40.042004
# 160539          1993 Hard Rd    Columbus    OH       43235  40.116903
# 160555       5729 N Hamilton    Columbus    OH       43230  40.073261
#
#         longitude  stars  review_count  is_open  \
# 132    -83.071415    4.0           162        1
# 144    -83.078730    3.0             8        1
# 149    -82.991044    4.0          1354        1
# 218    -83.125822    2.0            25        1
# 280    -82.880234    3.5             7        1
# ...           ...    ...           ...      ...
# 160447 -83.016595    3.5            35        1
# 160482 -83.002972    5.0             7        0
# 160535 -82.863357    3.5            19        0
# 160539 -83.068716    3.0            81        0
# 160555 -82.863418    3.0            81        1
#
#                                                attributes  \
# 132     {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 144     {'OutdoorSeating': 'False', 'RestaurantsAttire...
# 149     {'GoodForKids': 'True', 'HasTV': 'False', 'Res...
# 218     {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 280     {'Caters': 'True', 'BusinessAcceptsCreditCards...
# ...                                                   ...
# 160447  {'BusinessParking': '{'garage': False, 'street...
# 160482  {'GoodForKids': 'True', 'GoodForMeal': '{'dess...
# 160535  {'BusinessParking': '{'garage': False, 'street...
# 160539  {'RestaurantsTakeOut': 'True', 'WiFi': ''free'...
# 160555  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
#
#                                                categories  \
# 132                                  Chinese, Restaurants
# 144     Restaurants, Waffles, American (New), Diners, ...
# 149     Caterers, Bars, Sandwiches, Pubs, Restaurants,...
# 218     Fast Food, Restaurants, Food, Coffee & Tea, Bu...
# 280     International Grocery, Meat Shops, Specialty F...
# ...                                                   ...
# 160447                        American (New), Restaurants
# 160482  Breakfast & Brunch, Bakeries, Food Trucks, Foo...
# 160535  Food, Sandwiches, Desserts, Italian, Restauran...
# 160539  Bars, Nightlife, Event Planning & Services, Re...
# 160555  Breakfast & Brunch, Restaurants, American (Tra...
#
#                                                     hours
# 132     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 144     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 149     {'Monday': '0:0-0:0', 'Tuesday': '11:0-16:0', ...
# 218     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 280     {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...
# ...                                                   ...
# 160447                                               None
# 160482                                               None
# 160535  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 160539  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 160555  {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...
#
# [4344 rows x 14 columns]

# %%
df_attr = df_new[['business_id', 'attributes']]
df_attr.head()
# Out:
#                business_id                                         attributes
# 0   6iYb2HFDywm3zjuRg0shjw  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1   tCbdrRPZA0oiIYSmHG3J0w  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 5   D4JtQNTI4X3KcbzacDJsMw  {'GoodForKids': 'True', 'Alcohol': 'u'none'', ...
# 12  HPA_qyMEddpAEtFof02ixg  {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# 13  ufCxltuh56FF4-ZFZ6cVhg  {'BusinessParking': '{'garage': False, 'street...

# %%
df_test = df_ohio
df_test['attributes'] = df_test['attributes'].astype('str')
df_test['attributes'] = df_test['attributes'].apply(lambda x : dict(eval(x)) )
df_test2 = df_test["attributes"].apply(pd.Series)

df_test2
# Out:
# <ipython-input-6-0cb4c4db83e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['attributes'] = df_test['attributes'].astype('str')
# <ipython-input-6-0cb4c4db83e1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['attributes'] = df_test['attributes'].apply(lambda x : dict(eval(x)) )
#        GoodForKids RestaurantsGoodForGroups BikeParking RestaurantsTakeOut  \
# 132           True                     True        True               True
# 144           True                     True         NaN               True
# 149           True                     True        True               True
# 218          False                     True         NaN               True
# 280            NaN                      NaN        True               True
# ...            ...                      ...         ...                ...
# 160447        True                     True        True               True
# 160482        True                      NaN         NaN               True
# 160535        True                     True        True               True
# 160539        True                     True       False               True
# 160555        True                     True       False               True
#
#        OutdoorSeating RestaurantsReservations RestaurantsPriceRange2 Caters  \
# 132             False                    True                      2  False
# 144             False                   False                      1  False
# 149              None                   False                      2   True
# 218             False                   False                      1  False
# 280               NaN                     NaN                    NaN   True
# ...               ...                     ...                    ...    ...
# 160447          False                    True                      2   True
# 160482           True                   False                      1   True
# 160535           True                   False                      1   True
# 160539          False                   False                      2   True
# 160555          False                   False                      1  False
#
#        BusinessAcceptsCreditCards     WiFi  ... DriveThru GoodForDancing  \
# 132                          True    u'no'  ...       NaN            NaN
# 144                          True    u'no'  ...       NaN            NaN
# 149                          True    u'no'  ...       NaN            NaN
# 218                          True  u'free'  ...      True            NaN
# 280                          True      NaN  ...       NaN            NaN
# ...                           ...      ...  ...       ...            ...
# 160447                       True  u'free'  ...       NaN            NaN
# 160482                       True    u'no'  ...       NaN            NaN
# 160535                       True   'free'  ...       NaN            NaN
# 160539                       True   'free'  ...       NaN          False
# 160555                       True   'free'  ...       NaN            NaN
#
#                                                     Music Smoking Corkage  \
# 132                                                   NaN     NaN     NaN
# 144                                                   NaN     NaN     NaN
# 149                                                   NaN     NaN     NaN
# 218                                                   NaN     NaN     NaN
# 280                                                   NaN     NaN     NaN
# ...                                                   ...     ...     ...
# 160447                                                NaN     NaN     NaN
# 160482                                                NaN     NaN     NaN
# 160535                                                NaN     NaN     NaN
# 160539  {'dj': False, 'background_music': False, 'no_m...   u'no'     NaN
# 160555                                                NaN     NaN     NaN
#
#        BYOB                                         BestNights CoatCheck  \
# 132     NaN                                                NaN       NaN
# 144     NaN                                                NaN       NaN
# 149     NaN                                                NaN       NaN
# 218     NaN                                                NaN       NaN
# 280     NaN                                                NaN       NaN
# ...     ...                                                ...       ...
# 160447  NaN                                                NaN       NaN
# 160482  NaN                                                NaN       NaN
# 160535  NaN                                                NaN       NaN
# 160539  NaN  {'monday': False, 'tuesday': False, 'friday': ...     False
# 160555  NaN                                                NaN       NaN
#
#        RestaurantsCounterService DietaryRestrictions
# 132                          NaN                 NaN
# 144                          NaN                 NaN
# 149                          NaN                 NaN
# 218                          NaN                 NaN
# 280                          NaN                 NaN
# ...                          ...                 ...
# 160447                       NaN                 NaN
# 160482                       NaN                 NaN
# 160535                       NaN                 NaN
# 160539                       NaN                 NaN
# 160555                       NaN                 NaN
#
# [4344 rows x 35 columns]

# %%
df_test2.columns
# Out:
# Index(['GoodForKids', 'RestaurantsGoodForGroups', 'BikeParking',
#        'RestaurantsTakeOut', 'OutdoorSeating', 'RestaurantsReservations',
#        'RestaurantsPriceRange2', 'Caters', 'BusinessAcceptsCreditCards',
#        'WiFi', 'RestaurantsDelivery', 'HasTV', 'BusinessParking', 'Alcohol',
#        'RestaurantsTableService', 'RestaurantsAttire', 'Ambience',
#        'NoiseLevel', 'GoodForMeal', 'BYOBCorkage', 'ByAppointmentOnly',
#        'WheelchairAccessible', 'HappyHour', 'DogsAllowed',
#        'BusinessAcceptsBitcoin', 'DriveThru', 'GoodForDancing', 'Music',
#        'Smoking', 'Corkage', 'BYOB', 'BestNights', 'CoatCheck',
#        'RestaurantsCounterService', 'DietaryRestrictions'],
#       dtype='object')

# %%
df_test3 = df_test2.drop(['WiFi', 'Music', 'Smoking', 'BestNights', 'BusinessParking', 'Ambience', 'GoodForMeal'], axis =1)
df_test3
# Out:
#        GoodForKids RestaurantsGoodForGroups BikeParking RestaurantsTakeOut  \
# 132           True                     True        True               True
# 144           True                     True         NaN               True
# 149           True                     True        True               True
# 218          False                     True         NaN               True
# 280            NaN                      NaN        True               True
# ...            ...                      ...         ...                ...
# 160447        True                     True        True               True
# 160482        True                      NaN         NaN               True
# 160535        True                     True        True               True
# 160539        True                     True       False               True
# 160555        True                     True       False               True
#
#        OutdoorSeating RestaurantsReservations RestaurantsPriceRange2 Caters  \
# 132             False                    True                      2  False
# 144             False                   False                      1  False
# 149              None                   False                      2   True
# 218             False                   False                      1  False
# 280               NaN                     NaN                    NaN   True
# ...               ...                     ...                    ...    ...
# 160447          False                    True                      2   True
# 160482           True                   False                      1   True
# 160535           True                   False                      1   True
# 160539          False                   False                      2   True
# 160555          False                   False                      1  False
#
#        BusinessAcceptsCreditCards RestaurantsDelivery  ... HappyHour  \
# 132                          True               False  ...       NaN
# 144                          True               False  ...       NaN
# 149                          True                True  ...     False
# 218                          True                True  ...       NaN
# 280                          True                 NaN  ...       NaN
# ...                           ...                 ...  ...       ...
# 160447                       True               False  ...       NaN
# 160482                       True               False  ...       NaN
# 160535                       True                True  ...       NaN
# 160539                       True               False  ...      True
# 160555                       True                True  ...       NaN
#
#        DogsAllowed BusinessAcceptsBitcoin DriveThru GoodForDancing Corkage  \
# 132            NaN                    NaN       NaN            NaN     NaN
# 144            NaN                    NaN       NaN            NaN     NaN
# 149          False                  False       NaN            NaN     NaN
# 218            NaN                    NaN      True            NaN     NaN
# 280            NaN                    NaN       NaN            NaN     NaN
# ...            ...                    ...       ...            ...     ...
# 160447         NaN                    NaN       NaN            NaN     NaN
# 160482         NaN                    NaN       NaN            NaN     NaN
# 160535         NaN                    NaN       NaN            NaN     NaN
# 160539         NaN                    NaN       NaN          False     NaN
# 160555       False                    NaN       NaN            NaN     NaN
#
#        BYOB CoatCheck RestaurantsCounterService DietaryRestrictions
# 132     NaN       NaN                       NaN                 NaN
# 144     NaN       NaN                       NaN                 NaN
# 149     NaN       NaN                       NaN                 NaN
# 218     NaN       NaN                       NaN                 NaN
# 280     NaN       NaN                       NaN                 NaN
# ...     ...       ...                       ...                 ...
# 160447  NaN       NaN                       NaN                 NaN
# 160482  NaN       NaN                       NaN                 NaN
# 160535  NaN       NaN                       NaN                 NaN
# 160539  NaN     False                       NaN                 NaN
# 160555  NaN       NaN                       NaN                 NaN
#
# [4344 rows x 28 columns]

# %%
df_test3.columns
# Out:
# Index(['GoodForKids', 'RestaurantsGoodForGroups', 'BikeParking',
#        'RestaurantsTakeOut', 'OutdoorSeating', 'RestaurantsReservations',
#        'RestaurantsPriceRange2', 'Caters', 'BusinessAcceptsCreditCards',
#        'RestaurantsDelivery', 'HasTV', 'Alcohol', 'RestaurantsTableService',
#        'RestaurantsAttire', 'NoiseLevel', 'BYOBCorkage', 'ByAppointmentOnly',
#        'WheelchairAccessible', 'HappyHour', 'DogsAllowed',
#        'BusinessAcceptsBitcoin', 'DriveThru', 'GoodForDancing', 'Corkage',
#        'BYOB', 'CoatCheck', 'RestaurantsCounterService',
#        'DietaryRestrictions'],
#       dtype='object')

# %%
df_test3['GoodForKids'] = pd.get_dummies(df_test2['GoodForKids'])
df_test3['RestaurantsGoodForGroups'] = pd.get_dummies(df_test2['RestaurantsGoodForGroups'])
df_test3['BikeParking'] = pd.get_dummies(df_test2['BikeParking'])
df_test3['RestaurantsTakeOut'] = pd.get_dummies(df_test2['RestaurantsTakeOut'])
df_test3['OutdoorSeating'] = pd.get_dummies(df_test2['OutdoorSeating'])
df_test3['RestaurantsReservations'] = pd.get_dummies(df_test2['RestaurantsReservations'])
df_test3['RestaurantsPriceRange2'] = pd.get_dummies(df_test2['RestaurantsPriceRange2'])
df_test3['Caters'] = pd.get_dummies(df_test2['Caters'])
df_test3['BusinessAcceptsCreditCards'] = pd.get_dummies(df_test2['BusinessAcceptsCreditCards'])
df_test3['RestaurantsDelivery'] = pd.get_dummies(df_test2['RestaurantsDelivery'])
df_test3['HasTV'] = pd.get_dummies(df_test2['HasTV'])
df_test3['Alcohol'] = pd.get_dummies(df_test2['Alcohol'])
df_test3['RestaurantsTableService'] = pd.get_dummies(df_test2['RestaurantsTableService'])
df_test3['RestaurantsAttire'] = pd.get_dummies(df_test2['RestaurantsAttire'])
df_test3['NoiseLevel'] = pd.get_dummies(df_test2['NoiseLevel'])
df_test3['BYOBCorkage'] = pd.get_dummies(df_test2['BYOBCorkage'])
df_test3['ByAppointmentOnly'] = pd.get_dummies(df_test2['ByAppointmentOnly'])
df_test3['WheelchairAccessible'] = pd.get_dummies(df_test2['WheelchairAccessible'])
df_test3['HappyHour'] = pd.get_dummies(df_test2['HappyHour'])
df_test3['DogsAllowed'] = pd.get_dummies(df_test2['DogsAllowed'])
df_test3['BusinessAcceptsBitcoin'] = pd.get_dummies(df_test2['BusinessAcceptsBitcoin'])
df_test3['DriveThru'] = pd.get_dummies(df_test2['DriveThru'])
df_test3['GoodForDancing'] = pd.get_dummies(df_test2['GoodForDancing'])
df_test3['Corkage'] = pd.get_dummies(df_test2['Corkage'])
df_test3['BYOB'] = pd.get_dummies(df_test2['BYOB'])
df_test3['CoatCheck'] = pd.get_dummies(df_test2['CoatCheck'])
df_test3['RestaurantsCounterService'] = pd.get_dummies(df_test2['RestaurantsCounterService'])
df_test3['DietaryRestrictions'] = pd.get_dummies(df_test2['DietaryRestrictions'])
df_test3
# Out:
#         GoodForKids  RestaurantsGoodForGroups  BikeParking  \
# 132               0                         0            0
# 144               0                         0            0
# 149               0                         0            0
# 218               1                         0            0
# 280               0                         0            0
# ...             ...                       ...          ...
# 160447            0                         0            0
# 160482            0                         0            0
# 160535            0                         0            0
# 160539            0                         0            1
# 160555            0                         0            1
#
#         RestaurantsTakeOut  OutdoorSeating  RestaurantsReservations  \
# 132                      0               0                        0
# 144                      0               0                        1
# 149                      0               1                        1
# 218                      0               0                        1
# 280                      0               1                        0
# ...                    ...             ...                      ...
# 160447                   0               0                        0
# 160482                   0               1                        1
# 160535                   0               1                        1
# 160539                   0               0                        1
# 160555                   0               0                        1
#
#         RestaurantsPriceRange2  Caters  BusinessAcceptsCreditCards  \
# 132                          0       1                           0
# 144                          1       1                           0
# 149                          0       0                           0
# 218                          1       1                           0
# 280                          0       0                           0
# ...                        ...     ...                         ...
# 160447                       0       0                           0
# 160482                       1       0                           0
# 160535                       1       0                           0
# 160539                       0       0                           0
# 160555                       1       1                           0
#
#         RestaurantsDelivery  ...  HappyHour  DogsAllowed  \
# 132                       1  ...          0            0
# 144                       1  ...          0            0
# 149                       0  ...          1            1
# 218                       0  ...          0            0
# 280                       0  ...          0            0
# ...                     ...  ...        ...          ...
# 160447                    1  ...          0            0
# 160482                    1  ...          0            0
# 160535                    0  ...          0            0
# 160539                    1  ...          0            0
# 160555                    0  ...          0            1
#
#         BusinessAcceptsBitcoin  DriveThru  GoodForDancing  Corkage  BYOB  \
# 132                          0          0               0        0     0
# 144                          0          0               0        0     0
# 149                          1          0               0        0     0
# 218                          0          0               0        0     0
# 280                          0          0               0        0     0
# ...                        ...        ...             ...      ...   ...
# 160447                       0          0               0        0     0
# 160482                       0          0               0        0     0
# 160535                       0          0               0        0     0
# 160539                       0          0               1        0     0
# 160555                       0          0               0        0     0
#
#         CoatCheck  RestaurantsCounterService  DietaryRestrictions
# 132             0                          0                    0
# 144             0                          0                    0
# 149             0                          0                    0
# 218             0                          0                    0
# 280             0                          0                    0
# ...           ...                        ...                  ...
# 160447          0                          0                    0
# 160482          0                          0                    0
# 160535          0                          0                    0
# 160539          1                          0                    0
# 160555          0                          0                    0
#
# [4344 rows x 28 columns]

# %%
df_test = df_test.reset_index()
df_test.head()
# Out:
#    index             business_id                    name  \
# 0    132  5eq56X-e9YbAKmHgUOyXSg              Hunan Lion
# 1    144  Fl_7YDOMt58rTNHa7p2G4w            Waffle House
# 2    149  vecuat0jOia-CJveW3ngDw  Schmidt's Sausage Haus
# 3    218  ZaMMUcOIngBCgxuKxFzfqg              McDonald's
# 4    280  C1Jkjsqoz1AsYJy28IosQg    La Michoacana Market
#
#                 address        city state postal_code   latitude  longitude  \
# 0      2038 Crown Plaza    Columbus    OH       43220  40.065378 -83.071415
# 1         3085 Broadway  Urbancrest    OH       43123  39.900855 -83.078730
# 2      240 E Kossuth St    Columbus    OH       43206  39.946268 -82.991044
# 3  1524 Georgesville Rd    Columbus    OH       43228  39.919976 -83.125822
# 4    3160 S Hamilton Rd    Columbus    OH       43232  39.912139 -82.880234
#
#    stars  review_count  is_open  \
# 0    4.0           162        1
# 1    3.0             8        1
# 2    4.0          1354        1
# 3    2.0            25        1
# 4    3.5             7        1
#
#                                           attributes  \
# 0  {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 1  {'OutdoorSeating': 'False', 'RestaurantsAttire...
# 2  {'GoodForKids': 'True', 'HasTV': 'False', 'Res...
# 3  {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 4  {'Caters': 'True', 'BusinessAcceptsCreditCards...
#
#                                           categories  \
# 0                               Chinese, Restaurants
# 1  Restaurants, Waffles, American (New), Diners, ...
# 2  Caterers, Bars, Sandwiches, Pubs, Restaurants,...
# 3  Fast Food, Restaurants, Food, Coffee & Tea, Bu...
# 4  International Grocery, Meat Shops, Specialty F...
#
#                                                hours
# 0  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 1  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 2  {'Monday': '0:0-0:0', 'Tuesday': '11:0-16:0', ...
# 3  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 4  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...

# %%
df_test['attributes'] = df_test['attributes'].astype('str')
df_test['attributes'] = df_test['attributes'].str.replace('{','')
df_test['attributes'] = df_test['attributes'].str.replace('}','')
#df_test['attributes'] = df_test['attributes'].astype('str').str.split(',')
df_test
# Out:
#        index             business_id                          name  \
# 0        132  5eq56X-e9YbAKmHgUOyXSg                    Hunan Lion
# 1        144  Fl_7YDOMt58rTNHa7p2G4w                  Waffle House
# 2        149  vecuat0jOia-CJveW3ngDw        Schmidt's Sausage Haus
# 3        218  ZaMMUcOIngBCgxuKxFzfqg                    McDonald's
# 4        280  C1Jkjsqoz1AsYJy28IosQg          La Michoacana Market
# ...      ...                     ...                           ...
# 4339  160447  hNpnUFVW4Xm5CoShgpey7A  Bistro 2110 At the Blackwell
# 4340  160482  cDA3nKRBdx4IH_hAYGtcVg     The Early Bird Food Truck
# 4341  160535  furx9nQDLnKSx3gOxgbGHA           Grinders of Gahanna
# 4342  160539  pFRZvauzfaHeymvSGwNBXw                Senor Tequilas
# 4343  160555  cjyyjjBQXp2HdvlHKT_bCw                    Scramblers
#
#                    address        city state postal_code   latitude  \
# 0         2038 Crown Plaza    Columbus    OH       43220  40.065378
# 1            3085 Broadway  Urbancrest    OH       43123  39.900855
# 2         240 E Kossuth St    Columbus    OH       43206  39.946268
# 3     1524 Georgesville Rd    Columbus    OH       43228  39.919976
# 4       3160 S Hamilton Rd    Columbus    OH       43232  39.912139
# ...                    ...         ...   ...         ...        ...
# 4339   2110 Tuttle Park Pl    Columbus    OH       43210  40.005023
# 4340                          Columbus    OH       43201  40.006611
# 4341    921 E Johnstown Rd    Columbus    OH       43230  40.042004
# 4342          1993 Hard Rd    Columbus    OH       43235  40.116903
# 4343       5729 N Hamilton    Columbus    OH       43230  40.073261
#
#       longitude  stars  review_count  is_open  \
# 0    -83.071415    4.0           162        1
# 1    -83.078730    3.0             8        1
# 2    -82.991044    4.0          1354        1
# 3    -83.125822    2.0            25        1
# 4    -82.880234    3.5             7        1
# ...         ...    ...           ...      ...
# 4339 -83.016595    3.5            35        1
# 4340 -83.002972    5.0             7        0
# 4341 -82.863357    3.5            19        0
# 4342 -83.068716    3.0            81        0
# 4343 -82.863418    3.0            81        1
#
#                                              attributes  \
# 0     'GoodForKids': 'True', 'RestaurantsGoodForGrou...
# 1     'OutdoorSeating': 'False', 'RestaurantsAttire'...
# 2     'GoodForKids': 'True', 'HasTV': 'False', 'Rest...
# 3     'RestaurantsTakeOut': 'True', 'NoiseLevel': "u...
# 4     'Caters': 'True', 'BusinessAcceptsCreditCards'...
# ...                                                 ...
# 4339  'BusinessParking': "'garage': False, 'street':...
# 4340  'GoodForKids': 'True', 'GoodForMeal': "'desser...
# 4341  'BusinessParking': "'garage': False, 'street':...
# 4342  'RestaurantsTakeOut': 'True', 'WiFi': "'free'"...
# 4343  'RestaurantsAttire': "u'casual'", 'Restaurants...
#
#                                              categories  \
# 0                                  Chinese, Restaurants
# 1     Restaurants, Waffles, American (New), Diners, ...
# 2     Caterers, Bars, Sandwiches, Pubs, Restaurants,...
# 3     Fast Food, Restaurants, Food, Coffee & Tea, Bu...
# 4     International Grocery, Meat Shops, Specialty F...
# ...                                                 ...
# 4339                        American (New), Restaurants
# 4340  Breakfast & Brunch, Bakeries, Food Trucks, Foo...
# 4341  Food, Sandwiches, Desserts, Italian, Restauran...
# 4342  Bars, Nightlife, Event Planning & Services, Re...
# 4343  Breakfast & Brunch, Restaurants, American (Tra...
#
#                                                   hours
# 0     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 1     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 2     {'Monday': '0:0-0:0', 'Tuesday': '11:0-16:0', ...
# 3     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 4     {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...
# ...                                                 ...
# 4339                                               None
# 4340                                               None
# 4341  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 4342  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 4343  {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...
#
# [4344 rows x 15 columns]

# %%
df_merged = df_ohio.join(df_test3, how = 'outer')
